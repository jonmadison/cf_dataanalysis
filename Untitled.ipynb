# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pyplot

# %%
rap = pd.read_csv("./data/output-aceyalone.csv")

# %%
rap
# Out:
#      page       id                                              title  \
# 0       1     3578                                     The Guidelines
# 1       1     7382                            Rappers Rappers Rappers
# 2       1    94407                                 Everything Changes
# 3       1     7400                                        The Balance
# 4       1     7415                                       Dirty Birdie
# 5       1     7421                                      Rapps on Deck
# 6       1     7444                            Cornbread, Eddie and Me
# 7       1     7381                                   Master Your High
# 8       1     7407                           A Book of Human Language
# 9       1    39096                                        K.O. Player
# 10      2     7373                                  B-Boy Real Mc Coy
# 11      2     7443                                      Love and Hate
# ...
